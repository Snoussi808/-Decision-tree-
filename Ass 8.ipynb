# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder 
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.metrics import accuracy_score , ConfusionMatrixDisplay

# %% [markdown]
# # **Decision tree**

# %%
dp_test = pd.read_csv("C:/Users/snoussi/Desktop/pendigits-tes.csv")
dp_train = pd.read_csv("C:/Users/snoussi/Desktop/pendigits-tra.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dp_test = pd.read_csv("C:/Users/snoussi/Desktop/pendigits-tes.csv")
#       2 dp_train = pd.read_csv("C:/Users/snoussi/Desktop/pendigits-tra.csv")
#
# ...

# %%
dp_test.head()
# Out:
#     88   92    2   99   16   66   94   37   70    0    0.1   24   42   65  \
# 0   80  100   18   98   60   66  100   29   42    0      0   23   42   61
# 1    0   94    9   57   20   19    7    0   20   36     70   68  100  100
# 2   95   82   71  100   27   77   77   73  100   80     93   42   56   13
# 3   68  100    6   88   47   75   87   82   85   56    100   29   75    6
# 4   70  100  100   97   70   81   45   65   30   49     20   33    0   16
#
#    100  100.1   8
# 0   56     98   8
# 1   18     92   8
# 2    0      0   9
# 3    0      0   9
# 4    0      0   1

# %%
dp_train.head()
# Out:
#     47  100   27   81   57   37   26    0    0.1   23   56   53  100.1   90  \
# 0    0   89   27  100   42   75   29   45     15   15   37    0     69    2
# 1    0   57   31   68   72   90  100  100     76   75   50   51     28   25
# 2    0  100    7   92    5   68   19   45     86   34  100   45     74   23
# 3    0   67   49   83  100  100   81   80     60   60   40   40     33   20
# 4  100  100   88   99   49   74   17   47      0   16   37    0     73   16
#
#     40   98   8
# 0  100    6   2
# 1   16    0   1
# 2   67    0   4
# 3   47    0   1
# 4   20   20   6

# %%
dp_test.keys()
# Out:
# Index([' 88', ' 92', '  2', ' 99', ' 16', ' 66', ' 94', ' 37', ' 70', '  0',
#        '  0.1', ' 24', ' 42', ' 65', '100', '100.1', ' 8'],
#       dtype='object')

# %%
dp_train.keys()
# Out:
# Index([' 47', '100', ' 27', ' 81', ' 57', ' 37', ' 26', '  0', '  0.1', ' 23',
#        ' 56', ' 53', '100.1', ' 90', ' 40', ' 98', ' 8'],
#       dtype='object')

# %%
plt.subplot(4,4,1)
plt.scatter(dp_train[' 47'],dp_train[' 8'])
plt.subplot(4,4,2)
plt.scatter(dp_train['100'],dp_train[' 8'])
plt.subplot(4,4,3)
plt.scatter(dp_train[' 27'],dp_train[' 8'])
plt.subplot(4,4,4)
plt.scatter(dp_train[' 81'],dp_train[' 8'])
plt.subplot(4,4,5)
plt.scatter(dp_train[' 57'],dp_train[' 8'])
plt.subplot(4,4,6)
plt.scatter(dp_train[' 37'],dp_train[' 8'])
plt.subplot(4,4,7)
plt.scatter(dp_train[' 26'],dp_train[' 8'])
plt.subplot(4,4,8)
plt.scatter(dp_train['  0'],dp_train[' 8'])
plt.subplot(4,4,9)
plt.scatter(dp_train['  0.1'],dp_train[' 8'])
plt.subplot(4,4,10)
plt.scatter(dp_train[' 23'],dp_train[' 8'])
plt.subplot(4,4,11)
plt.scatter(dp_train[' 56'],dp_train[' 8'])
plt.subplot(4,4,12)
plt.scatter(dp_train[' 53'],dp_train[' 8'])
plt.subplot(4,4,13)
plt.scatter(dp_train['100.1'],dp_train[' 8'])
plt.subplot(4,4,14)
plt.scatter(dp_train[' 90'],dp_train[' 8'])
plt.subplot(4,4,15)
plt.scatter(dp_train[' 40'],dp_train[' 8'])
plt.subplot(4,4,16)
plt.scatter(dp_train[' 98'],dp_train[' 8'])

# %%
plt.subplot(4,4,1)
plt.scatter(dp_test[' 88'],dp_test[' 8'])
plt.subplot(4,4,2)
plt.scatter(dp_test[' 92'],dp_test[' 8'])
plt.subplot(4,4,3)
plt.scatter(dp_test['  2'],dp_test[' 8'])
plt.subplot(4,4,4)
plt.scatter(dp_test[' 99'],dp_test[' 8'])
plt.subplot(4,4,5)
plt.scatter(dp_test[' 16'],dp_test[' 8'])
plt.subplot(4,4,6)
plt.scatter(dp_test[' 66'],dp_test[' 8'])
plt.subplot(4,4,7)
plt.scatter(dp_test[' 94'],dp_test[' 8'])
plt.subplot(4,4,8)
plt.scatter(dp_test[' 37'],dp_test[' 8'])
plt.subplot(4,4,9)
plt.scatter(dp_test[' 70'],dp_test[' 8'])
plt.subplot(4,4,10)
plt.scatter(dp_test['  0'],dp_test[' 8'])
plt.subplot(4,4,11)
plt.scatter(dp_test['  0.1'],dp_test[' 8'])
plt.subplot(4,4,12)
plt.scatter(dp_test[' 24'],dp_test[' 8'])
plt.subplot(4,4,13)
plt.scatter(dp_test[' 42'],dp_test[' 8'])
plt.subplot(4,4,14)
plt.scatter(dp_test[' 65'],dp_test[' 8'])
plt.subplot(4,4,15)
plt.scatter(dp_test['100'],dp_test[' 8'])
plt.subplot(4,4,16)
plt.scatter(dp_test['100.1'],dp_test[' 8'])

# %%
fig, ax =plt.subplots(figsize=(11, 9))
plt.title("Correlation Plot")
sns.heatmap(dp_train)
# Out:
# <Axes: title={'center': 'Correlation Plot'}>

# %%
fig, ax =plt.subplots(figsize=(11, 9))
plt.title("Correlation Plot")
sns.heatmap(dp_test)
# Out:
# <Axes: title={'center': 'Correlation Plot'}>

# %%
x_train = dp_train.drop([' 8'],axis=1)
y_train = dp_train[' 8']

# %%
td_model = DecisionTreeClassifier()
td_model.fit(x_train,y_train)
train_predic = td_model.predict(x_train)
print('Train Accuracy Model',accuracy_score(y_train,train_predic))
print('Train Confusion Matrix Display Model',ConfusionMatrixDisplay(train_predic))
# Out:
# Train Accuracy Model 1.0
# Train Confusion Matrix Display Model <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001F76FB47DA0>

# %%
fig = plt.figure(figsize=(,4),dpi= 300)
tree.plot_tree(
    td_model,
    feature_names = dp_train.drop([' 8'],axis = 1),
    class_names = dp_train[' 8'],
    filled = True,
    rounded = True
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 13
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 2
#       1 fig = plt.figure(figsize=(3,4),dpi= 300)
# ----> 2 tree.plot_tree(
# ...

# %%
td_model = DecisionTreeClassifier(splitter= 'random',min_samples_split=5)
td_model.fit(x_train,y_train)
train_predic = td_model.predict(x_train)
print('Train Accuracy Model',accuracy_score(y_train,train_predic))
print('Train Confusion Matrix Display Model',ConfusionMatrixDisplay(train_predic))
# Out:
# Train Accuracy Model 0.991058321099693
# Train Confusion Matrix Display Model <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001F76FE86210>

# %% [markdown]
# # **Bagging**

# %%
x_test = dp_test.drop([' 8'],axis=1)
y_test = dp_test[' 8']

# %%
td_model = DecisionTreeClassifier(splitter= 'random',min_samples_split=5)
td_model.fit(x_test,y_test)
test_predic = td_model.predict(x_test)
print('Train Accuracy Model',accuracy_score(y_test,test_predic))
print('Train Confusion Matrix Display Model',ConfusionMatrixDisplay(test_predic))
# Out:
# Train Accuracy Model 0.989705461824421
# Train Confusion Matrix Display Model <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001F76E3B76E0>

# %%
svm = SVC()
svm.fit(x_test,y_test)
test_predic = td_model.predict(x_test)
print('Train Accuracy Model',accuracy_score(y_test,test_predic))
print('Train Confusion Matrix Display Model',ConfusionMatrixDisplay(test_predic))
# Out:
# Train Accuracy Model 0.989705461824421
# Train Confusion Matrix Display Model <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001F76FBC5B80>

# %%
rl_model = RandomForestClassifier()

# %%
rl_model.fit(x_train,y_train)
print('Train Accuracy Model',accuracy_score(y_test,test_predic))
print('Train Confusion Matrix Display Model',ConfusionMatrixDisplay(test_predic))
# Out:
# Train Accuracy Model 0.989705461824421
# Train Confusion Matrix Display Model <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001F766F54890>

# %%
for i in (10, 50, 100, 150, 200):
     rl_modelg = RandomForestClassifier(n_estimators= i , min_samples_leaf= 10 , max_samples= 200)
     rl_modelg.fit(x_test,y_test)
     print('Train Accuracy Model',accuracy_score(y_test,test_predic))
     print('Train Confusion Matrix Display Model',ConfusionMatrixDisplay(test_predic))
# Out:
# Train Accuracy Model 0.989705461824421
# Train Confusion Matrix Display Model <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001F7739C0AA0>
# Train Accuracy Model 0.989705461824421
# Train Confusion Matrix Display Model <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001F7739C08F0>
# Train Accuracy Model 0.989705461824421
# Train Confusion Matrix Display Model <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001F7739C0AA0>
# Train Accuracy Model 0.989705461824421
# Train Confusion Matrix Display Model <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001F7739C08F0>
# Train Accuracy Model 0.989705461824421
# Train Confusion Matrix Display Model <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001F7739C0AA0>
